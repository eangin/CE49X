# %% [markdown]
# # CE49X: Introduction to Computational Thinking and Data Science for Civil Engineers
# ## Week 1 Lab: Environment Setup Verification
#
# **Instructor:** Dr. Eyuphan Koc
# **Department of Civil Engineering, Bogazici University**
# **Semester:** Spring 2026
#
# ---

# %% [markdown]
# ## Overview
#
# This lab verifies that your development environment is fully set up and ready for the course. There is no coding required — just run each cell and provide screenshots as proof.
#
# **Submission:**
# - Rename this notebook to `Week01_Lab_FirstnameLastname.ipynb`
# - Complete all sections below
# - Make sure the notebook runs top-to-bottom without errors (Kernel → Restart & Run All)
# - Commit and push to your fork before the deadline
#
# **Estimated time:** 2–3 hours (including installation)
#
# ---

# %% [markdown]
# ## Student Information
#
# Fill in your details in the cell below.

# %%
# Fill in your information
student_name = "Emir Ali Angın"       # e.g. "Ahmet Yilmaz"
student_id = "2022403078"         # e.g. "2021400123"
github_username = "eangin"    # e.g. "ahmetyilmaz"

print(f"Name:     {student_name}")
print(f"ID:       {student_id}")
print(f"GitHub:   {github_username}")
# Out:
# Name:     Emir Ali Angın
# ID:       2022403078
# GitHub:   eangin

# %% [markdown]
# ---
# ## Task 1: Python & Anaconda
#
# Run the cell below. It should print your Python version (3.10 or higher required) and confirm Anaconda/Miniconda is installed.

# %%
import sys
import platform

print(f"Python version: {sys.version}")
print(f"Platform:       {platform.system()} {platform.machine()}")
print(f"Executable:     {sys.executable}")

# Check Python version
major, minor = sys.version_info[:2]
if major >= 3 and minor >= 10:
    print(f"\nPython {major}.{minor} — OK")
else:
    print(f"\nWARNING: Python {major}.{minor} found. Version 3.10+ is required.")
# Out:
# Python version: 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# Platform:       Windows AMD64
# Executable:     c:\Users\ASUS\anaconda3\python.exe
#
# Python 3.13 — OK

# %% [markdown]
# ---
# ## Task 2: Core Libraries
#
# Run the cell below to verify that all required libraries are installed. All four should show a version number and print **OK**.

# %%
import importlib

required = {
    "numpy":       "np",
    "pandas":      "pd",
    "matplotlib":  "mpl",
    "sklearn":     "sklearn"
}

all_ok = True
for package, alias in required.items():
    try:
        mod = importlib.import_module(package)
        version = getattr(mod, "__version__", "installed")
        print(f"{package:15s} {version:15s} OK")
    except ImportError:
        print(f"{package:15s} {'MISSING':15s} FAIL")
        all_ok = False

print()
if all_ok:
    print("All core libraries installed.")
else:
    print("Some libraries are missing. See CE49X_Setup_Guide.ipynb for installation instructions.")
# Out:
# numpy           2.3.5           OK
# pandas          2.3.3           OK
# matplotlib      3.10.6          OK
# sklearn         1.7.2           OK
#
# All core libraries installed.

# %% [markdown]
# ---
# ## Task 3: Quick Smoke Test
#
# Run the cell below. If everything is set up correctly, it will produce a small plot. This confirms NumPy, Pandas, and Matplotlib all work together.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate sample civil engineering data
np.random.seed(42)
cement_content = np.array([250, 300, 350, 400, 450])  # kg/m³
compressive_strength = 0.08 * cement_content + np.random.normal(0, 2, 5)  # MPa

fig, ax = plt.subplots(figsize=(6, 3.5))
ax.scatter(cement_content, compressive_strength, color='steelblue', s=80, zorder=3)
ax.set_xlabel('Cement Content (kg/m³)')
ax.set_ylabel('Compressive Strength (MPa)')
ax.set_title('Concrete Mix — Smoke Test')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("Smoke test passed — NumPy, Pandas, and Matplotlib are working.")
# Out:
# Smoke test passed — NumPy, Pandas, and Matplotlib are working.

# %% [markdown]
# ---
# ## Task 4: IDE Setup — Cursor (or VS Code)
#
# Confirm that you have **Cursor** (recommended) or VS Code installed and can open Jupyter notebooks in it.
#
# **Instructions:**
# 1. Open this notebook file in Cursor (or VS Code)
# 2. Take a screenshot showing the notebook open in the editor
# 3. Paste/drag the screenshot into the markdown cell below
#
# > **Tip:** You can drag and drop an image file directly into a markdown cell in Cursor/VS Code, or reference it with `![screenshot](screenshot.png)` if you save it in this folder.

# %% [markdown]
# **YOUR SCREENSHOT HERE** — Replace this text with your screenshot showing the IDE.
#
# ![alt text](scre.png)

# %% [markdown]
# ---
# ## Task 5: Agentic Coding Assistant — Claude Code or Gemini CLI
#
# You need **at least one** agentic CLI tool installed. Choose whichever you prefer:
#
# | Tool | Install Command | Notes |
# |------|----------------|-------|
# | **Claude Code** | `npm install -g @anthropic-ai/claude-code` | Requires Node.js and an Anthropic API key |
# | **Gemini CLI** | `npm install -g @anthropic-ai/gemini-cli` or see Google docs | Free with your Bogazici Google account |
#
# **Instructions:**
# 1. Open a terminal
# 2. Run your chosen tool (e.g. type `claude` or `gemini`)
# 3. Ask it a simple question, such as: *"What is the formula for beam deflection?"*
# 4. Take a screenshot of the interaction
# 5. Paste it into the markdown cell below

# %% [markdown]
# **YOUR SCREENSHOT HERE** — Replace this text with your screenshot showing the CLI assistant.
# ![alt text](<Ekran görüntüsü 2026-02-17 033520.png>)

# %%
# Which tool did you set up? Uncomment the one you chose.

#cli_tool = "Claude Code"
cli_tool = "Gemini CLI"
# cli_tool = "Both"

print(f"Agentic CLI tool: {cli_tool}")
# Out:
# Agentic CLI tool: Gemini CLI

# %% [markdown]
# ---
# ## Task 6: Git & GitHub
#
# This is the most important setup task. You need to confirm that:
# 1. Git is installed
# 2. You have forked the course repository
# 3. You have cloned your fork locally
# 4. You have set up the `upstream` remote
#
# Run the cell below from **inside your cloned repository folder**.

# %%
import subprocess

def run(cmd):
    result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
    return result.stdout.strip() if result.returncode == 0 else f"ERROR: {result.stderr.strip()}"

print(f"Git version:   {run('git --version')}")
print(f"Git user.name: {run('git config user.name')}")
print(f"Git user.email:{run('git config user.email')}")
print()
print("Remotes:")
print(run('git remote -v'))
# Out:
# Git version:   git version 2.53.0.windows.1
# Git user.name: eangin
# Git user.email:emir.angin@std.bogazici.com.tr
#
# Remotes:
# origin	https://github.com/eangin/CE49X.git (fetch)
# origin	https://github.com/eangin/CE49X.git (push)

# %% [markdown]
# **Verify the output above shows:**
# - `origin` pointing to **your fork** (`github.com/<your-username>/CE49X`)
# - `upstream` pointing to the **course repository**
#
# If `upstream` is missing, go back to `SUBMISSION_GUIDELINES.md` Section 1 and add it.

# %% [markdown]
# **Take a screenshot** of your GitHub fork page (showing the forked repository in your browser) and paste it below.

# %% [markdown]
# **YOUR SCREENSHOT HERE** — Replace this text with your screenshot of your GitHub fork.
# ![alt text](<Ekran görüntüsü 2026-02-17 040118.png>)

# %% [markdown]
# ---
# ## Final Checklist
#
# Before submitting, set each item to `True` in the cell below.

# %%
checklist = {
    "Python 3.10+ installed":            True,
    "NumPy, Pandas, Matplotlib, Scikit-learn installed": True,
    "Smoke test plot displayed":          True,
    "Cursor (or VS Code) screenshot":     True,
    "Claude Code or Gemini CLI screenshot": True,
    "Git installed and configured":       True,
    "Course repo forked and cloned":      True,
    "Upstream remote added":              True,
}

done = sum(v for v in checklist.values())
total = len(checklist)

for item, status in checklist.items():
    mark = "[x]" if status else "[ ]"
    print(f"  {mark} {item}")

print(f"\nCompleted: {done}/{total}")
if done == total:
    print("All done — ready to submit!")
else:
    print("Please complete the remaining items before submitting.")
# Out:
#   [x] Python 3.10+ installed
#   [x] NumPy, Pandas, Matplotlib, Scikit-learn installed
#   [x] Smoke test plot displayed
#   [x] Cursor (or VS Code) screenshot
#   [x] Claude Code or Gemini CLI screenshot
#   [x] Git installed and configured
#   [x] Course repo forked and cloned
#   [x] Upstream remote added
#
# Completed: 8/8
# All done — ready to submit!

# %% [markdown]
# ---
# ## How to Submit
#
# 1. Rename this notebook: `Week01_Lab_FirstnameLastname.ipynb`
# 2. Restart kernel and run all cells (make sure no errors)
# 3. Commit and push:
#
# ```bash
# git add Week01_Python_Fundamentals/lab/Week01_Lab_FirstnameLastname.ipynb
# git commit -m "Submit Week 01 lab — environment setup verification"
# git push origin main
# ```
#
# > **Key Insight: First Push**
# > This is your very first push to the course repository. If it works, your entire Git workflow is confirmed!

# %% [markdown]
# ---
#
# ### Questions?
#
# **Dr. Eyuphan Koc**
# eyuphan.koc@bogazici.edu.tr
